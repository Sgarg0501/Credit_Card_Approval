# %%
import pandas as pd
import matplotlib.pyplot as plt

credit=pd.read_csv('Credit_Card_Approval/credit_record.csv')
application=pd.read_csv('Credit_Card_Approval/application_record.csv')
credit
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
application
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df = pd.merge(application, credit, how='inner', on='ID')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['ID'].value_counts()
# Out:
# 5090630    61
# 5148524    61
# 5066707    61
# 5061848    61
# 5118380    61
#            ..
# 5024557     1
# 5062311     1
# 5024365     1
# 5024364     1
# 5041568     1
# Name: ID, Length: 36457, dtype: int64

# %%
#Definitely duplicacy of rows is there in data as we have rows with same id
df=df.drop_duplicates(subset='ID')
df.reset_index(inplace=True,drop=True)

# %%
df.isnull().sum()
# Out:
# ID                         0
# CODE_GENDER                0
# FLAG_OWN_CAR               0
# FLAG_OWN_REALTY            0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# NAME_HOUSING_TYPE          0
# DAYS_BIRTH                 0
# DAYS_EMPLOYED              0
# FLAG_MOBIL                 0
# FLAG_WORK_PHONE            0
# FLAG_PHONE                 0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        11323
# CNT_FAM_MEMBERS            0
# MONTHS_BALANCE             0
# STATUS                     0
# dtype: int64

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 6211
# Core staff               3591
# Sales staff              3485
# Managers                 3012
# Drivers                  2138
# High skill tech staff    1383
# Accountants              1241
# Medicine staff           1207
# Cooking staff             655
# Security staff            592
# Cleaning staff            551
# Private service staff     344
# Low-skill Laborers        175
# Waiters/barmen staff      174
# Secretaries               151
# HR staff                   85
# Realty agents              79
# IT staff                   60
# Name: OCCUPATION_TYPE, dtype: int64

# %%
x=df['OCCUPATION_TYPE'].isnull().sum()
print(x)
y=df.shape[0]
print(y)
ans=x/y*100
print("null values percentage in occupation column",ans,"%")
# Out:
# 11323
# 36457
# null values percentage in occupation column 31.05850728255205 %

# %%
#Filling these data values with other
df['OCCUPATION_TYPE'].fillna(value='Other', inplace=True)
df['OCCUPATION_TYPE'].head()
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\generic.py:6383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# 0             Other
# 1             Other
# 2    Security staff
# 3       Sales staff
# 4       Sales staff
# Name: OCCUPATION_TYPE, dtype: object

# %%
df.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# MONTHS_BALANCE         0
# STATUS                 0
# dtype: int64

# %%
df['CODE_GENDER'].value_counts()
# Out:
# F    24430
# M    12027
# Name: CODE_GENDER, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['CODE_GENDER']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df
# Out:
#             ID  CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1            Y               Y             0
# 1      5008805            1            Y               Y             0
# 2      5008806            1            Y               Y             0
# 3      5008808            0            N               Y             0
# 4      5008809            0            N               Y             0
# ...        ...          ...          ...             ...           ...
# 36452  5149828            1            Y               Y             0
# 36453  5149834            0            N               Y             0
# 36454  5149838            0            N               Y             0
# 36455  5150049            0            N               Y             0
# 36456  5150337            1            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['FLAG_OWN_CAR'].value_counts()
# Out:
# N    22614
# Y    13843
# Name: FLAG_OWN_CAR, dtype: int64

# %%
df['FLAG_OWN_REALTY'].value_counts()
# Out:
# Y    24506
# N    11951
# Name: FLAG_OWN_REALTY, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

cols_to_encode = ['FLAG_OWN_CAR','FLAG_OWN_REALTY']
encoder = OrdinalEncoder()

df[cols_to_encode] = encoder.fit_transform(df[cols_to_encode])
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1           1.0              1.0             0
# 1      5008805            1           1.0              1.0             0
# 2      5008806            1           1.0              1.0             0
# 3      5008808            0           0.0              1.0             0
# 4      5008809            0           0.0              1.0             0
# ...        ...          ...           ...              ...           ...
# 36452  5149828            1           1.0              1.0             0
# 36453  5149834            0           0.0              1.0             0
# 36454  5149838            0           0.0              1.0             0
# 36455  5150049            0           0.0              1.0             0
# 36456  5150337            1           0.0              1.0             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['STATUS'].value_counts()
# Out:
# C    17950
# X     9669
# 0     8456
# 1      276
# 5       76
# 2       19
# 3        6
# 4        5
# Name: STATUS, dtype: int64

# %%
df.describe()
# Out:
#                  ID   CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  3.645700e+04  36457.000000  36457.000000     36457.000000
# mean   5.078227e+06      0.329895      0.379708         0.672189
# std    4.187524e+04      0.470181      0.485321         0.469422
# min    5.008804e+06      0.000000      0.000000         0.000000
# 25%    5.042028e+06      0.000000      0.000000         0.000000
# 50%    5.074614e+06      0.000000      0.000000         1.000000
# 75%    5.115396e+06      1.000000      1.000000         1.000000
# max    5.150487e+06      1.000000      1.000000         1.000000
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  36457.000000      3.645700e+04  36457.000000   36457.000000
# mean       0.430315      1.866857e+05 -15975.173382   59262.935568
# std        0.742367      1.017892e+05   4200.549944  137651.334859
# min        0.000000      2.700000e+04 -25152.000000  -15713.000000
# ...

# %%
for i in range (df.shape[0]):
    if df['STATUS'][i]=='C' or df['STATUS'][i]=='0' or df['STATUS'][i]=='X':
        df['STATUS'][i]=0
    else:
        df['STATUS'][i]=1
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Shreya\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# Married                 25048
# Single / not married     4829
# Civil marriage           2945
# Separated                2103
# Widow                    1532
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
df['STATUS']=df['STATUS'].astype(int)
df['FLAG_OWN_CAR']=df['FLAG_OWN_CAR'].astype(int)
df['FLAG_OWN_REALTY']=df['FLAG_OWN_REALTY'].astype(int)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1             1                1             0
# 1      5008805            1             1                1             0
# 2      5008806            1             1                1             0
# 3      5008808            0             0                1             0
# 4      5008809            0             0                1             0
# ...        ...          ...           ...              ...           ...
# 36452  5149828            1             1                1             0
# 36453  5149834            0             0                1             0
# 36454  5149838            0             0                1             0
# 36455  5150049            0             0                1             0
# 36456  5150337            1             0                1             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['CNT_CHILDREN'].value_counts()
# Out:
# 0     25201
# 1      7492
# 2      3256
# 3       419
# 4        63
# 5        20
# 14        3
# 7         2
# 19        1
# Name: CNT_CHILDREN, dtype: int64

# %%
df['AMT_INCOME_TOTAL'].value_counts()
df.describe()
# Out:
#                  ID   CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# count  3.645700e+04  36457.000000  36457.000000     36457.000000
# mean   5.078227e+06      0.329895      0.379708         0.672189
# std    4.187524e+04      0.470181      0.485321         0.469422
# min    5.008804e+06      0.000000      0.000000         0.000000
# 25%    5.042028e+06      0.000000      0.000000         0.000000
# 50%    5.074614e+06      0.000000      0.000000         1.000000
# 75%    5.115396e+06      1.000000      1.000000         1.000000
# max    5.150487e+06      1.000000      1.000000         1.000000
#
#        CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  36457.000000      3.645700e+04  36457.000000   36457.000000
# mean       0.430315      1.866857e+05 -15975.173382   59262.935568
# std        0.742367      1.017892e+05   4200.549944  137651.334859
# min        0.000000      2.700000e+04 -25152.000000  -15713.000000
# ...

# %%
#income standardisation
from sklearn.preprocessing import StandardScaler
large_col = 'AMT_INCOME_TOTAL'
scaler = StandardScaler()
scaler.fit(df[[large_col]])
df[large_col] = scaler.transform(df[[large_col]])
df
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1             1                1             0
# 1      5008805            1             1                1             0
# 2      5008806            1             1                1             0
# 3      5008808            0             0                1             0
# 4      5008809            0             0                1             0
# ...        ...          ...           ...              ...           ...
# ...

# %%
df['FLAG_MOBIL'].value_counts()
# Out:
# 1    36457
# Name: FLAG_MOBIL, dtype: int64

# %%
df.drop(columns='FLAG_MOBIL',inplace=True)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:4908: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df['NAME_INCOME_TYPE'].value_counts()
# Out:
# Working                 18819
# Commercial associate     8490
# Pensioner                6152
# State servant            2985
# Student                    11
# Name: NAME_INCOME_TYPE, dtype: int64

# %%
#can't give priority to any one col in 'name income type' , so label encoding
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['NAME_INCOME_TYPE']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
import seaborn as sns
sns.distplot(df['NAME_INCOME_TYPE'])
plt.title('Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
df['NAME_EDUCATION_TYPE'].value_counts()
# Out:
# Secondary / secondary special    24777
# Higher education                  9864
# Incomplete higher                 1410
# Lower secondary                    374
# Academic degree                     32
# Name: NAME_EDUCATION_TYPE, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['NAME_EDUCATION_TYPE']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
sns.distplot(df['NAME_EDUCATION_TYPE'])
plt.title('Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# Married                 25048
# Single / not married     4829
# Civil marriage           2945
# Separated                2103
# Widow                    1532
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['NAME_FAMILY_STATUS']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)

# %%
sns.distplot(df['NAME_FAMILY_STATUS'], kde=True, hist=False, kde_kws={'bw': 1.0})
plt.title('Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# 1    25048
# 3     4829
# 0     2945
# 2     2103
# 4     1532
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# House / apartment      32548
# With parents            1776
# Municipal apartment     1128
# Rented apartment         575
# Office apartment         262
# Co-op apartment          168
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['NAME_HOUSING_TYPE']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# 1    32548
# 5     1776
# 2     1128
# 4      575
# 3      262
# 0      168
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
sns.distplot(df['NAME_HOUSING_TYPE'], kde=True, hist=False, kde_kws={'bw': 1.0})

plt.title('Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# Other                    11323
# Laborers                  6211
# Core staff                3591
# Sales staff               3485
# Managers                  3012
# Drivers                   2138
# High skill tech staff     1383
# Accountants               1241
# Medicine staff            1207
# Cooking staff              655
# Security staff             592
# Cleaning staff             551
# Private service staff      344
# Low-skill Laborers         175
# Waiters/barmen staff       174
# Secretaries                151
# HR staff                    85
# Realty agents               79
# IT staff                    60
# Name: OCCUPATION_TYPE, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['OCCUPATION_TYPE']
encoder = LabelEncoder()

df[cols_to_encode] = df[cols_to_encode].apply(encoder.fit_transform)

# %%
sns.distplot(df['OCCUPATION_TYPE'], kde=True, hist=False, kde_kws={'bw': 1.0})

plt.title('Distribution Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)

# Fit the K-means model to the data
kmeans.fit(df)

# Get the cluster labels for each data point
labels = kmeans.labels_

# Get the cluster centers
centers = kmeans.cluster_centers_

# Print the cluster labels and centers
print("Cluster Labels:", labels)
print("Cluster Centers:", centers)
# Out:
# Cluster Labels: [1 1 1 ... 1 1 1]
# Cluster Centers: [[ 5.07465008e+06  1.46699267e-01  2.09779951e-01  7.69356153e-01
#    5.02037490e-02 -3.74257122e-01  1.00000000e+00  3.46242869e+00
#    1.62281989e+00  1.05199674e+00 -2.17681961e+04  3.65243000e+05
#   -2.23987495e-14  2.88182559e-01  3.48818256e-02  1.20000000e+01
#    1.74865526e+00 -6.01075795e+00  9.12795436e-03]
#  [ 5.07895071e+06  3.66961282e-01  4.14088780e-01  6.52529517e-01
#    5.07222479e-01  7.57228232e-02  2.68108964e+00  3.02328342e+00
#    1.31630499e+00  1.32959567e+00 -1.48030807e+04 -2.64550369e+03
#    2.71156256e-01  2.96154607e-01  1.00817888e-01  8.59804762e+00
#    2.28945980e+00 -5.79559396e+00  1.07512697e-02]]

# %%
from sklearn.metrics import silhouette_score
silhouette_avg = silhouette_score(df, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.8689319283618938

# %%
from sklearn.cluster import DBSCAN
import numpy as np
dbscan = DBSCAN(eps=1.0, min_samples=1)
dbscan.fit(df)
labels = dbscan.labels_
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[dbscan.core_sample_indices_] = True
print("Cluster labels:", labels)
print("Number of clusters:", n_clusters)
print("Indices of core samples:", dbscan.core_sample_indices_)
# Out:
# Cluster labels: [    0     0     1 ... 25152 25153 25154]
# Number of clusters: 25155
# Indices of core samples: [    0     1     2 ... 36454 36455 36456]

# %%
labels = dbscan.labels_
silhouette_avg = silhouette_score(df, labels)
print("Silhouette Score:", silhouette_avg)    #value ranges between -1 to 1
# Out:
# Silhouette Score: 0.34408272077379215

# %%
from sklearn.cluster import MeanShift
meanshift = MeanShift()
meanshift.fit(df)
labels = meanshift.labels_
cluster_centers = meanshift.cluster_centers_
n_clusters = len(cluster_centers)
print("Cluster labels:", labels)
print("Cluster centers:", cluster_centers)
print("Number of clusters:", n_clusters)
# Out:
# Cluster labels: [0 0 0 ... 0 0 0]
# Cluster centers: [[ 5.07895071e+06  3.66961282e-01  4.14088780e-01  6.52529517e-01
#    5.07222479e-01  7.57228232e-02  2.68108964e+00  3.02328342e+00
#    1.31630499e+00  1.32959567e+00 -1.48030807e+04 -2.64550369e+03
#    2.71156256e-01  2.96154607e-01  1.00817888e-01  8.59804762e+00
#    2.28945980e+00 -5.79559396e+00  1.07512697e-02]
#  [ 5.07465008e+06  1.46699267e-01  2.09779951e-01  7.69356153e-01
#    5.02037490e-02 -3.74257122e-01  1.00000000e+00  3.46242869e+00
#    1.62281989e+00  1.05199674e+00 -2.17681961e+04  3.65243000e+05
#    0.00000000e+00  2.88182559e-01  3.48818256e-02  1.20000000e+01
#    1.74865526e+00 -6.01075795e+00  9.12795436e-03]]
# Number of clusters: 2

# %%
silhouette_avg = silhouette_score(df, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.8689319283618938
